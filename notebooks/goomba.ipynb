# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

import os.path as op
base_dir = '/scr/fluidspace/pkerp/projects/genbank'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyspark.sql import *
sqlContext = SQLContext(sc)
# get the gene_id -> pubmed mapping
gene2pubmed = (sc.textFile(op.join(base_dir, "data/gene2pubmed"))
                 .filter(lambda x: x[0] != '#')
                 .map(lambda x: x.split('\t'))
                 .map(lambda p: {'taxid': int(p[0]), 'geneid': int(p[1]), 'pmid': int(p[2]), 'count': 1}))

# %%
gene_neighbors = (sc.textFile(op.join(base_dir, "data/gene_neighbors"))
                 .filter(lambda x: x[0] != '#')
                 .map(lambda x: x.split('\t'))
                 .map(lambda p:   { 'taxid': int(p[0]), 
                                    'geneid' :int(p[1]), 
                                    'start_pos': p[4],
                                    'end_pos': p[5],
                                    'nucleotide_accession': p[2],
                                    'chr': p[7],
                                    'orientation': p[6],
                                    'assembly': p[13]}))


gene_info = (sc.textFile(op.join(base_dir, "data/gene_info"))
             .filter(lambda x: x[0] != '#')
             .map(lambda x: x.split('\t'))
             .map(lambda x: { 'taxid': int(x[0]),
                              'geneid': int(x[1]),
                              'description': x[8],
                              'symbol': x[2],
                              'name': x[11],
                              'type_of_gene': x[9]}))

# %%
gene_info_keyed = gene_info.map(lambda x: ((x['taxid'], x['geneid']), x))

# %%
# filter for human genes
human_gene_pubmed = (gene2pubmed.filter(lambda x: x['taxid'] == 9606)
                                .map(lambda x: ((x['taxid'], x['geneid']), x)))

# %%
def reduce_count(r1, r2):
    '''
    A reduce function that simply counts the number of elements in the table.
    
    @param r1: A Row
    @param r2: A Row
    @return: A new Row, equal to the first Row with a summed count.
    '''
    #print >>sys.stderr, "r1:", r1
    r1['count'] += r2['count']
    return r1

# %%
# count how many references each id has
# ((taxid, geneid), row)
counted_human_gene_pubmed = (human_gene_pubmed.reduceByKey(reduce_count))
counted_human_gene_pubmed.take(1)
# Out:
# [((9606, 7748), {'count': 13, 'geneid': 7748, 'pmid': 1602151, 'taxid': 9606})]

# %%
def merge_two_dicts(x, y):
    '''Given two dicts, merge them into a new dict as a shallow copy.'''
    z = x.copy()
    z.update(y)
    return z

# %%
# filter the gene_neighbors to those in the human GRCh38 assembly
# ((taxid, geneid), row)
human_neighbors = (gene_neighbors.filter(lambda x: x['assembly'].find('GRCh38') >= 0)
                           .filter(lambda x: x['assembly'].find('Primary') >= 0)
                           .map(lambda x: ((x['taxid'], x['geneid']), x)))

human_neighbors_info = (human_neighbors.join(gene_info_keyed)
                    .map(lambda x: (x[0], merge_two_dicts(x[1][0], x[1][1]))))
human_neighbors_info.take(1)
# Out:
# [((9606, 100287188),
#   {'assembly': u'Reference GRCh38.p2 Primary Assembly',
#    'chr': u'-',
#    'description': u'family with sequence similarity 104, member B pseudogene',
#    'end_pos': u'51691',
#    'geneid': 100287188,
#    'name': u'-',
#    'nucleotide_accession': u'NT_113930.2',
#    'orientation': u'-',
#    'start_pos': u'51139',
#    'symbol': u'LOC100287188',
#    'taxid': 9606,
#    'type_of_gene': u'pseudo'})]

# %%
# join (K,V) and (K,W) -> (K, (V,W)) pairs
# map (K,(V,W)) -> (K,W)
# join the genes with reference counts with the gene_neighbors information
human_neighbors_info_pubmed = (counted_human_gene_pubmed.join(human_neighbors_info)
                      .map(lambda x: ((x[1][0]['count'], x[0][0], x[0][1]), x[1][1])))
                      #.map(lambda x: x['start_end_pos'] = (x['nucleotide_accession'], x['orientation'], x['start_pos'], x['end_pos']))
human_neighbors_info_pubmed.take(1)
# Out:
# [((18, 9606, 121536),
#   {'assembly': u'Reference GRCh38.p2 Primary Assembly',
#    'chr': u'12',
#    'description': u'AE binding protein 2',
#    'end_pos': u'19522238',
#    'geneid': 121536,
#    'name': u'AE binding protein 2',
#    'nucleotide_accession': u'NC_000012.12',
#    'orientation': u'+',
#    'start_pos': u'19439491',
#    'symbol': u'AEBP2',
#    'taxid': 9606,
#    'type_of_gene': u'protein-coding'})]

# %%
def consolidate_start_and_end(r):
    '''
    Consolidate the start and end rows
    from a row.
    
    :param r: (key, {'start_pos': 1000, 'end_pos': 1010})
    :return: (key, {'start_end_pos': set((1000, 1010))}
    '''
    r[1]['start_end_pos'] = set([(r[1]['chr'], r[1]['orientation'],int(r[1]['start_pos']), int(r[1]['end_pos']))])
    return (r[0], r[1])

def reduce_by_start_end_pos(r1,r2):
    '''
    Reduce all of the rows by their start / send positions.
    
    :param r: {'start_end_pos': set((1000, 1010))}
    '''
    #print >>sys.stderr, "r1:", r1
    r1['start_end_pos'] = r1['start_end_pos'].union(r2['start_end_pos'])
    return r1

# %%
reduced_human_neighbors_info_pubmed = (human_neighbors_info_pubmed.map(consolidate_start_and_end)
                               .reduceByKey(reduce_by_start_end_pos))

              
reduced_human_neighbors_info_pubmed.sortByKey(ascending=False)
reduced_human_neighbors_info_pubmed.take(1)
# Out:
# [((1, 9606, 100189342),
#   {'assembly': u'Reference GRCh38.p2 Primary Assembly',
#    'chr': u'10',
#    'description': u'transfer RNA-Val (TAC) 3-1',
#    'end_pos': u'5853782',
#    'geneid': 100189342,
#    'name': u'transfer RNA-Val (TAC) 3-1',
#    'nucleotide_accession': u'NC_000010.11',
#    'orientation': u'-',
#    'start_end_pos': {(u'10', u'-', 5853710, 5853782)},
#    'start_pos': u'5853710',
#    'symbol': u'TRV-TAC3-1',
#    'taxid': 9606,
#    'type_of_gene': u'tRNA'})]

# %%
# take every (chr, orientation, start, end) tuple from the set and create one
# big list out of it
# then convert it all to TSV strings
flattened_human_neighbors_info_pubmed = (reduced_human_neighbors_info_pubmed.flatMap(
                                 lambda x: [[x[0][0], x[1]['geneid'], x[1]['symbol'], x[1]['name']] + list(y) for y in x[1]['start_end_pos']])
                                 .map(lambda x: "\t".join(map(str, x)) + "\n")) 
all_values = flattened_human_neighbors_info_pubmed.collect()

# %%
with open('/scr/fluidspace/pkerp/projects/goomba/output/genes_by_popularity.tsv', 'w') as f:
    f.write('count\tgeneid\tsymbol\tname\tchr\torientation\tstart\tend\n')
    f.writelines(all_values)

# %% [markdown]
# ## Getting top RNA genes

# %%
gene_info.take(1)
# Out:
# [{'description': u'Record to support submission of GeneRIFs for a gene not in Gene (Azorhizobium caulinodans Dreyfus et al. 1988; Azotirhizobium caulinodans.  Use when strain, subtype, isolate, etc. is unspecified, or when different from all specified ones in Gene.).',
#   'geneid': 5692769,
#   'name': u'-',
#   'symbol': u'NEWENTRY',
#   'taxid': 7,
#   'type_of_gene': u'other'}]

# %%
rna_gene_info = (gene_info
 .filter(lambda x: x['type_of_gene'] != 'other')
 .filter(lambda x: x['type_of_gene'] != 'protein-coding')
 .filter(lambda x: x['type_of_gene'] != 'pseudo')
 .map(lambda x: ((x['taxid'], x['geneid']), x)))
rna_gene_info.take(1)
# Out:
# [((394, 7788539),
#   {'description': u'ncRNA',
#    'geneid': 7788539,
#    'name': u'-',
#    'symbol': u'NGR_b08000',
#    'taxid': 394,
#    'type_of_gene': u'ncRNA'})]

# %%
counted_rna_gene_info = (rna_gene_info
                         .join(counted_human_gene_pubmed)
                         .map(lambda x: ((x[1][1]['count'], x[0][0], x[0][1]), x))
                         .sortByKey(ascending=False)
                         )
nc_rnas = counted_rna_gene_info.collect()

# %%
nc_rnas[:10]
# Out:
# [((419, 9606, 406991),
#   ((9606, 406991),
#    ({'description': u'microRNA 21',
#      'geneid': 406991,
#      'name': u'microRNA 21',
#      'symbol': u'MIR21',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 419, 'geneid': 406991, 'pmid': 11679670, 'taxid': 9606}))),
#  ((224, 9606, 406938),
#   ((9606, 406938),
#    ({'description': u'microRNA 146a',
#      'geneid': 406938,
#      'name': u'microRNA 146a',
#      'symbol': u'MIR146A',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 224, 'geneid': 406938, 'pmid': 12007417, 'taxid': 9606}))),
#  ((220, 9606, 100189401),
#   ((9606, 100189401),
#    ({'description': u'transfer RNA-Ile (AAT) 7-2',
#      'geneid': 100189401,
#      'name': u'transfer RNA-Ile (AAT) 7-2',
#      'symbol': u'TRI-AAT7-2',
#      'taxid': 9606,
#      'type_of_gene': u'tRNA'},
#     {'count': 220, 'geneid': 100189401, 'pmid': 17554300, 'taxid': 9606}))),
#  ((216, 9606, 406947),
#   ((9606, 406947),
#    ({'description': u'microRNA 155',
#      'geneid': 406947,
#      'name': u'microRNA 155',
#      'symbol': u'MIR155',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 216, 'geneid': 406947, 'pmid': 12007417, 'taxid': 9606}))),
#  ((177, 9606, 407040),
#   ((9606, 407040),
#    ({'description': u'microRNA 34a',
#      'geneid': 407040,
#      'name': u'microRNA 34a',
#      'symbol': u'MIR34A',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 177, 'geneid': 407040, 'pmid': 12554860, 'taxid': 9606}))),
#  ((151, 9606, 406937),
#   ((9606, 406937),
#    ({'description': u'microRNA 145',
#      'geneid': 406937,
#      'name': u'microRNA 145',
#      'symbol': u'MIR145',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 151, 'geneid': 406937, 'pmid': 12007417, 'taxid': 9606}))),
#  ((136, 9606, 7012),
#   ((9606, 7012),
#    ({'description': u'telomerase RNA component',
#      'geneid': 7012,
#      'name': u'telomerase RNA component',
#      'symbol': u'TERC',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 136, 'geneid': 7012, 'pmid': 7544491, 'taxid': 9606}))),
#  ((131, 9606, 407006),
#   ((9606, 407006),
#    ({'description': u'microRNA 221',
#      'geneid': 407006,
#      'name': u'microRNA 221',
#      'symbol': u'MIR221',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 131, 'geneid': 407006, 'pmid': 12624257, 'taxid': 9606}))),
#  ((109, 9606, 283120),
#   ((9606, 283120),
#    ({'description': u'H19, imprinted maternally expressed transcript (non-protein coding)',
#      'geneid': 283120,
#      'name': u'H19, imprinted maternally expressed transcript (non-protein coding)',
#      'symbol': u'H19',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 109, 'geneid': 283120, 'pmid': 1688465, 'taxid': 9606}))),
#  ((104, 9606, 406952),
#   ((9606, 406952),
#    ({'description': u'microRNA 17',
#      'geneid': 406952,
#      'name': u'microRNA 17',
#      'symbol': u'MIR17',
#      'taxid': 9606,
#      'type_of_gene': u'ncRNA'},
#     {'count': 104, 'geneid': 406952, 'pmid': 11679670, 'taxid': 9606})))]

# %%
for nc in nc_rnas[:500]:
    nc_info = nc[1][1][0]
    print nc_info['geneid']
# Out:
# 406991
# 406938
# 100189401
# 406947
# 407040
# 406937
# 7012
# 407006
# 283120
# 406952
# 406906
# 100048912
# 406935
# 407007
# 406913
# 407021
# 406950
# 406881
# 406992
# 407018
# 406988
# 406973
# 406985
# 4549
# 407008
# 4567
# 407035
# 406984
# 406986
# 406983
# 7839
# 574501
# 406982
# 406948
# 100124700
# 407015
# 406903
# 406942
# 406928
# 406911
# 407004
# 406996
# 406958
# 560
# 406907
# 10984
# 494324
# 407029
# 406940
# 407975
# 406933
# 407041
# 406910
# 406892
# 50652
# 55384
# 407042
# 407046
# 406995
# 406989
# 407050
# 406904
# 406900
# 406941
# 406934
# 406893
# 7503
# 574411
# 406971
# 378938
# 406901
# 407053
# 407026
# 407000
# 406953
# 406932
# 407012
# 407010
# 406976
# 406955
# 406922
# 125050
# 5820
# 407024
# 407019
# 406954
# 406902
# 407043
# 407009
# 406967
# 406921
# 50941
# 10866
# 442904
# 407011
# 406979
# 406972
# 406961
# 406899
# 574447
# 442890
# 407014
# 406919
# 6315
# 574452
# 407048
# 406959
# 6023
# 4574
# 102724766
# 407028
# 406885
# 406884
# 406987
# 442920
# 407055
# 406943
# 442918
# 407017
# 406915
# 406890
# 574506
# 574455
# 494327
# 407037
# 406994
# 406929
# 554210
# 406966
# 406912
# 407031
# 51214
# 50818
# 554213
# 494336
# 442901
# 406931
# 406920
# 55000
# 6066
# 4566
# 643714
# 574456
# 494335
# 442915
# 407030
# 407013
# 406936
# 619552
# 442900
# 407054
# 407039
# 407033
# 406980
# 406883
# 282706
# 114614
# 442891
# 406997
# 406968
# 406960
# 406957
# 406949
# 406918
# 283131
# 100033819
# 442917
# 442909
# 407051
# 407022
# 406993
# 406978
# 406891
# 406882
# 60674
# 100126355
# 100126299
# 693159
# 574032
# 442892
# 406924
# 145624
# 8847
# 4550
# 724033
# 652995
# 574031
# 442906
# 407049
# 407047
# 407034
# 407032
# 407002
# 406975
# 406951
# 406925
# 406909
# 51352
# 10301
# 1283
# 101805488
# 619554
# 442912
# 442893
# 406999
# 406969
# 406917
# 406916
# 406914
# 406905
# 406888
# 388815
# 386607
# 378805
# 157273
# 10255
# 100151683
# 693122
# 441108
# 407027
# 406977
# 406956
# 406908
# 406894
# 406886
# 29931
# 10230
# 100533107
# 100359403
# 100126333
# 693235
# 574444
# 574413
# 574412
# 494332
# 494330
# 442919
# 442916
# 442913
# 442902
# 407056
# 407045
# 407036
# 407020
# 407001
# 406981
# 406974
# 406946
# 406930
# 406923
# 125144
# 26827
# 4568
# 101928376
# 101867536
# 664617
# 574453
# 574448
# 574443
# 574434
# 574408
# 574034
# 574033
# 442903
# 407044
# 407025
# 406998
# 406965
# 406963
# 406944
# 406895
# 406889
# 64002
# 26871
# 6060
# 4565
# 1867
# 100131814
# 693223
# 693210
# 693193
# 693169
# 693123
# 574504
# 574466
# 494337
# 494325
# 442914
# 442911
# 442908
# 442907
# 442894
# 440823
# 407023
# 406990
# 406962
# 406896
# 406887
# 338433
# 26835
# 10547
# 3478
# 2489
# 101927324
# 100507098
# 100303453
# 100126356
# 100126336
# 100008589
# 780851
# 729582
# 727677
# 723778
# 693120
# 677775
# 574507
# 574496
# 574479
# 574457
# 574450
# 574449
# 574436
# 494323
# 442905
# 407016
# 401237
# 285834
# 253018
# 118425
# 90768
# 84981
# 84677
# 80862
# 23642
# 7217
# 4569
# 618
# 101929231
# 101928165
# 100885779
# 100642175
# 100507308
# 100316868
# 100302276
# 100302246
# 100302150
# 100188856
# 100144632
# 100130460
# 100126343
# 100033822
# 100033818
# 100033817
# 100033816
# 100033815
# 100033814
# 100033813
# 100033812
# 100033811
# 100033810
# 100033809
# 100033808
# 100033807
# 100033806
# 100033805
# 100033804
# 100033803
# 100033802
# 100033801
# 100033800
# 100033799
# 100033603
# 100033460
# 100033458
# 100033456
# 100033455
# 100033454
# 100033453
# 100033451
# 100033450
# 100033449
# 100033448
# 100033447
# 100033446
# 100033445
# 100033444
# 100033443
# 100033442
# 100033441
# 100033440
# 100033437
# 728655
# 693190
# 645323
# 643911
# 574511
# 574480
# 574474
# 574451
# 554202
# 494326
# 442910
# 442897
# 441951
# 407003
# 406964
# 406945
# 406927
# 386593
# 349114
# 347689
# 284260
# 150967
# 149830
# 149775
# 112597
# 57291
# 57061
# 27004
# 26781
# 25859
# 9808
# 9383
# 8123
# 6043
# 6029
# 4572
# 3378
# 2221
# 102724137
# 101929710
# 101929222
# 101928694
# 101752399
# 101669764
# 100652933
# 100526833
# 100507056
# 100507053
# 100506023
# 100505832
# 100423036
# 100422992
# 100422912
# 100422893
# 100302692
# 100302263
# 100302221
# 100302201
# 100302133
# 100302129
# 100302115
# 100289178
# 100271873
# 100130889
# 100126337
# 100126334
# 100126317
# 100008588
# 768213
# 724025
# 693218
# 693189
# 693175
# 646576
# 645520
# 619563
# 619555
# 619553
# 574515
# 574458
# 574445
# 574442
# 574441
# 574435
# 574409
# 554214
# 497258
# 494331
# 494328
# 442899
# 442898
# 407052
# 406926
# 404266
# 401022
# 400955
# 400550
# 399959
# 399717
# 388796
# 353125
# 352961
# 348249
# 347745
# 339789
# 339201
# 284900
# 284440
# 257203
